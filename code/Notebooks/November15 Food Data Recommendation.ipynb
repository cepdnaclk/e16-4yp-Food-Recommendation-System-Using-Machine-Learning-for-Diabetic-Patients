# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !pip install pandas_bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas_bokeh
#   Downloading pandas_bokeh-0.5.5-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from pandas_bokeh) (1.3.5)
# Requirement already satisfied: bokeh>=2.0 in /usr/local/lib/python3.7/dist-packages (from pandas_bokeh) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (7.1.2)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (6.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (21.3)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (6.0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (2.8.2)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (1.21.6)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (4.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=2.0->pandas_bokeh) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=2.0->pandas_bokeh) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->pandas_bokeh) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=2.0->pandas_bokeh) (1.15.0)
# Installing collected packages: pandas-bokeh
# Successfully installed pandas-bokeh-0.5.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import distance

# %%
import pandas_bokeh
# Embedding plots in Jupyter/Colab Notebook
pandas_bokeh.output_notebook()

# %%
df =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset/SOM_FoodData_Nov15.csv')

# %%
# Calculate saturated fat as a percentage of total fat
fat_column = (df["Saturated Fat (g)"]/df["Fats (g)"])*100

# %%
df_category = df.copy()
df_category["Saturated Fat (g)"] = fat_column

# %%
labels = ["low","medium", "high"]
# Cut of criteria
cut_off_values = {
    "Calories (kcal)":(100,200),
    "Protein (g)": (10, 20),
    "Fats (g)": (5,15),
    "Carbs (g)": (10, 30),
    "Fiber (g)": (1, 5),
    "Sugar (g)": (2, 12),
    "Phosphorus (mg)": (100, 300),
    "Potassium (mg)": (100, 300),
    "Sodium (mg)": (500, 1000),
    "Saturated Fat (g)": (20, 50),
    "Trans Fat (g)": (0.5, 2)
}

# %%
# Apply cutoff margins
for key,values in cut_off_values.items():
  cond_list = [df_category[key].between(0, values[0],"left"), df_category[key].between(values[0], values[1],"both"), df_category[key].between(values[1], np.inf,"neither")]
  df_category[key] = np.select(cond_list, ["low", "medium", "high"], 0)

# %%
df_category.to_csv(r'/gdrive/Shareddrives/FYP Project/Dataset/with_cutoff_values.csv')

# %%
df_category
# Out:
#      Unnamed: 0                                               Name  \
# 0             0                              Bread, wheat, toasted
# 1             1  Biscuits, plain or buttermilk, prepared from r...
# 2             2       Bread, french or vienna (includes sourdough)
# 3             3  Cake, chocolate, prepared from recipe without ...
# 4             4             Cake, fruitcake, commercially prepared
# ..          ...                                                ...
# 545         545           Tomato juice, canned, without salt added
# 546         546                                    Pimento, canned
# 547         547                          Broccoli, chinese, cooked
# 548         548                              Cabbage, napa, cooked
# 549         549                           Fungi, Cloud ears, dried
#
#               Group  GI Calories (kcal) Protein (g) Fats (g) Carbs (g)  \
# 0    baked-products   1            high      medium      low      high
# 1    baked-products   0            high         low     high      high
# 2    baked-products   1            high      medium      low      high
# 3    baked-products   0            high         low     high      high
# 4    baked-products   0            high         low   medium      high
# ..              ...  ..             ...         ...      ...       ...
# 545      vegetables   0             low         low      low       low
# 546      vegetables   0             low         low      low       low
# 547      vegetables   0             low         low      low       low
# 548      vegetables   0             low         low      low       low
# 549      vegetables   0            high         low      low      high
#
#     Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg) Sodium (mg)  \
# 0      medium    medium          medium         medium      medium
# 1      medium    medium          medium         medium      medium
# 2      medium    medium          medium         medium      medium
# 3      medium       low          medium         medium         low
# 4      medium      high             low         medium         low
# ..        ...       ...             ...            ...         ...
# 545       low    medium             low         medium         low
# 546    medium    medium             low         medium         low
# 547    medium       low             low         medium         low
# 548       low       low             low            low         low
# 549      high       low          medium           high         low
#
#     Saturated Fat (g) Trans Fat (g)  Category   wx    wy
# 0              medium           low         1  2.5   2.0
# 1              medium           low         1  2.5   4.0
# 2              medium           low         3  1.0   3.0
# 3              medium           low         3  0.5   2.0
# 4                 low           low         0  6.0   7.0
# ..                ...           ...       ...  ...   ...
# 545               low           low         1  1.5   8.0
# 546               low           low         1  1.5   8.0
# 547               low           low         3  2.5   8.0
# 548               low           low         1  0.5   8.0
# 549               low           low         0  5.5  10.0
#
# [550 rows x 18 columns]

# %%
df_category['Calories (kcal)'].value_counts()
# Out:
# high      262
# low       197
# medium     91
# Name: Calories (kcal), dtype: int64

# %%
# Create a copy of data set
df_std = df_category.copy()

# %%
df_std["Group"].unique()
# Out:
# array(['baked-products', 'beverages', 'diary', 'fast-foods', 'fruits',
#        'grains', 'greens', 'meals-entrees-side-dishes', 'meat',
#        'mashrooms', 'nuts', 'oils-and-sauces', 'seafood', 'soups',
#        'spices', 'sweets', 'vegetables'], dtype=object)

# %%
GI_high_food = df_std[df_std["GI"]==2]

# %%
GI_high_food
# Out:
#      Unnamed: 0                                               Name  \
# 5             5            Cake, gingerbread, prepared from recipe
# 11           11  Cookies, graham crackers, plain or honey (incl...
# 15           15   Crackers, saltines (includes oyster, soda, soup)
# 19           19                                    Croutons, plain
# 33           33               Waffles, plain, prepared from recipe
# 34           34  Leavening agents, baking powder, double-acting...
# 37           37  English muffins, plain, unenriched, without ca...
# 47           47             Alcoholic beverage, beer, regular, all
# 72           72  Alcoholic beverage, liqueur, coffee with cream...
# 119         119                   Ice cream, soft serve, chocolate
# 123         123  Nuts, coconut milk, raw (liquid expressed from...
# 128         128                    Fast foods, nachos, with cheese
# 131         131  Fast foods, chicken fillet sandwich, plain wit...
# 137         137                         Fast foods, potato, mashed
# 172         172                                       Pummelo, raw
# 177         177                                    Watermelon, raw
# 189         189                                     Jackfruit, raw
# 206         206                                 Yardlong bean, raw
# 208         208                           Beans, fava, in pod, raw
# 231         231                             Amaranth grain, cooked
# 237         237                                        Millet, raw
# 244         244  Wheat flour, white, all-purpose, enriched, ble...
# 251         251  Cereals, oats, instant, fortified, plain, prep...
# 259         259         Rice, white, glutinous, unenriched, cooked
# 302         302                                   Tamales (Navajo)
# 442         442                                 Spices, anise seed
# 456         456                                   Cookies, fortune
# 457         457              Snacks, pretzels, hard, plain, salted
# 458         458             Candies, gumdrops, starch jelly pieces
# 478         478                                Candies, jellybeans
# 491         491                                 Syrups, corn, dark
# 495         495                                  Syrups, grenadine
# 512         512                                      Parsnips, raw
# 514         514                      Potatoes, flesh and skin, raw
# 517         517                                     Rutabagas, raw
# 519         519                                       Turnips, raw
# 530         530                                       Cassava, raw
#
#                          Group  GI Calories (kcal) Protein (g) Fats (g)  \
# 5               baked-products   2            high         low     high
# 11              baked-products   2            high         low   medium
# 15              baked-products   2            high         low   medium
# 19              baked-products   2            high      medium   medium
# 33              baked-products   2            high         low   medium
# 34              baked-products   2             low         low      low
# 37              baked-products   2            high         low      low
# 47                   beverages   2             low         low      low
# 72                   beverages   2            high         low     high
# 119                      diary   2            high         low   medium
# 123                      diary   2            high         low     high
# 128                 fast-foods   2            high         low     high
# 131                 fast-foods   2            high      medium   medium
# 137                 fast-foods   2             low         low      low
# 172                     fruits   2             low         low      low
# 177                     fruits   2             low         low      low
# 189                     fruits   2             low         low      low
# 206                     grains   2             low         low      low
# 208                     grains   2             low         low      low
# 231                     grains   2          medium         low      low
# 237                     grains   2            high      medium      low
# 244                     grains   2            high      medium      low
# 251                     grains   2             low         low      low
# 259                     grains   2             low         low      low
# 302  meals-entrees-side-dishes   2          medium         low   medium
# 442                     spices   2            high      medium     high
# 456                     sweets   2            high         low      low
# 457                     sweets   2            high      medium      low
# 458                     sweets   2            high         low      low
# 478                     sweets   2            high         low      low
# 491                     sweets   2            high         low      low
# 495                     sweets   2            high         low      low
# 512                 vegetables   2             low         low      low
# 514                 vegetables   2             low         low      low
# 517                 vegetables   2             low         low      low
# 519                 vegetables   2             low         low      low
# 530                 vegetables   2          medium         low      low
#
#     Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg) Sodium (mg)  \
# 5        high       low       low             low           high         low
# 11       high    medium      high          medium         medium         low
# 15       high    medium       low          medium         medium      medium
# 19       high      high       low          medium         medium      medium
# 33       high       low       low          medium         medium      medium
# 34     medium       low       low            high            low        high
# 37       high    medium       low          medium         medium         low
# 47        low       low       low             low            low         low
# 72     medium       low      high             low            low         low
# 119    medium       low      high          medium         medium         low
# 123       low    medium    medium          medium         medium         low
# 128      high    medium    medium          medium           high         low
# 131    medium    medium    medium          medium         medium      medium
# 137    medium    medium       low             low         medium         low
# 172       low    medium       low             low         medium         low
# 177       low       low    medium             low         medium         low
# 189    medium    medium      high             low           high         low
# 206       low       low       low             low         medium         low
# 208    medium      high    medium          medium           high         low
# 231    medium    medium       low          medium         medium         low
# 237      high      high       low          medium         medium         low
# 244      high    medium       low          medium         medium         low
# 251    medium    medium       low             low            low         low
# 259    medium    medium       low             low            low         low
# 302    medium    medium       low             low         medium         low
# 442      high      high       low            high           high         low
# 456      high    medium      high             low            low         low
# 457      high    medium    medium          medium         medium        high
# 458      high       low      high             low            low         low
# 478      high       low      high             low            low         low
# 491      high       low      high             low            low         low
# 495      high       low      high             low            low         low
# 512    medium    medium    medium             low           high         low
# 514    medium    medium       low             low           high         low
# 517       low    medium    medium             low           high         low
# 519       low    medium    medium             low         medium         low
# 530      high    medium       low             low         medium         low
#
#     Saturated Fat (g) Trans Fat (g)  Category   wx    wy
# 5              medium           low         1  2.5   4.0
# 11                low           low         2  6.5   8.0
# 15                low           low         3  1.5   2.0
# 19             medium           low         1  2.5   2.0
# 33             medium           low         3  1.0   1.0
# 34                  0           low         2  8.0  11.0
# 37                low           low         3  1.5   4.0
# 47                  0           low         1  0.5   8.0
# 72               high           low         0  8.0   5.0
# 119              high           low         3  4.5   6.0
# 123              high           low         0  7.5   4.0
# 128               low           low         1  2.5   4.0
# 131               low           low         3  2.0   1.0
# 137            medium           low         3  1.5   6.0
# 172               low           low         1  1.5   8.0
# 177               low           low         3 -0.5   8.0
# 189            medium           low         1  4.0   7.0
# 206            medium           low         1  1.0   7.0
# 208               low           low         3  3.5  10.0
# 231               low           low         1  1.0   5.0
# 237               low           low         0  7.0   9.0
# 244               low           low         3  1.5   2.0
# 251               low           low         1  1.0   9.0
# 259            medium           low         3 -0.5  12.0
# 302            medium           low         1  0.0   5.0
# 442               low           low         0  7.0  11.0
# 456            medium           low         2  8.0   7.0
# 457               low           low         3  1.5   2.0
# 458                 0           low         2  8.0   7.0
# 478               low           low         2  8.0   7.0
# 491                 0           low         2  8.0   7.0
# 495                 0           low         2  8.0   7.0
# 512               low           low         3  3.0   9.0
# 514            medium           low         3  2.5   6.0
# 517               low           low         3  2.5   8.0
# 519               low           low         1  1.5   8.0
# 530            medium           low         3  2.0   5.0

# %%
random_food = GI_high_food.loc[[177]]

# %%
random_food
# Out:
#      Unnamed: 0             Name   Group  GI Calories (kcal) Protein (g)  \
# 177         177  Watermelon, raw  fruits   2             low         low
#
#     Fats (g) Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg)  \
# 177      low       low       low    medium             low         medium
#
#     Sodium (mg) Saturated Fat (g) Trans Fat (g)  Category   wx   wy
# 177         low               low           low         3 -0.5  8.0

# %%
df_std.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Group', 'GI', 'Calories (kcal)', 'Protein (g)',
#        'Fats (g)', 'Carbs (g)', 'Fiber (g)', 'Sugar (g)', 'Phosphorus (mg)',
#        'Potassium (mg)', 'Sodium (mg)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Category', 'wx', 'wy'],
#       dtype='object')

# %%
selected_match = df_std[(df_std["GI"]==0) & (df_std["Group"]=="fruits") & (df_std["Category"]==3)]

# %%
distance_column = selected_match.apply(lambda x : np.sqrt((x.wx-(-0.5))**2 + (x.wy-8.0)**2), axis=1 )

# %%
selected_match.loc[distance_column.sort_values().index[:5],:]
# Out:
#      Unnamed: 0                                               Name   Group  \
# 201         201                  Cloudberries, raw (Alaska Native)  fruits
# 188         188   Groundcherries, (cape-gooseberries or poha), raw  fruits
# 180         180  Cranberry, low bush or lingenberry, raw (Alask...  fruits
# 152         152           Grapefruit, raw, pink and red, all areas  fruits
# 197         197                                       Soursop, raw  fruits
#
#      GI Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 201   0             low         low      low       low       low       low
# 188   0             low         low      low    medium       low       low
# 180   0             low         low      low    medium       low       low
# 152   0             low         low      low    medium    medium    medium
# 197   0             low         low      low    medium    medium      high
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g)  \
# 201             low            low         low               low
# 188             low            low         low               low
# 180             low            low         low               low
# 152             low         medium         low               low
# 197             low         medium         low               low
#
#     Trans Fat (g)  Category   wx    wy
# 201           low         3  0.0   9.0
# 188           low         3  0.0   9.0
# 180           low         3  0.0   9.0
# 152           low         3  0.5  10.0
# 197           low         3  1.0  11.0

# %%
def recommend_food(selected_food, df_std):
  # Get data from selected food
  gi=selected_food["GI"].values[0]
  cat=selected_food["Category"].values[0]
  group=selected_food["Group"].values[0]
  wx=selected_food["wx"].values[0]
  wy=selected_food["wy"].values[0]

  # Select matching food considering GI, Group, Category
  selected_match = df_std[(df_std["GI"] < gi) & (df_std["Group"]==group) & (df_std["Category"]==cat)]
  # Calculate eucleadian distance
  distance_column = selected_match.apply(lambda x : np.sqrt((x.wx- wx)**2 + (x.wy-wy)**2), axis=1 )
  # return top 5 matching foods
  return selected_match.loc[distance_column.sort_values().index[:5],:]

# %%
recommend_food(random_food, df_std)
# Out:
#      Unnamed: 0                                               Name   Group  \
# 201         201                  Cloudberries, raw (Alaska Native)  fruits
# 188         188   Groundcherries, (cape-gooseberries or poha), raw  fruits
# 180         180  Cranberry, low bush or lingenberry, raw (Alask...  fruits
# 152         152           Grapefruit, raw, pink and red, all areas  fruits
# 197         197                                       Soursop, raw  fruits
#
#      GI Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 201   0             low         low      low       low       low       low
# 188   0             low         low      low    medium       low       low
# 180   0             low         low      low    medium       low       low
# 152   0             low         low      low    medium    medium    medium
# 197   0             low         low      low    medium    medium      high
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g)  \
# 201             low            low         low               low
# 188             low            low         low               low
# 180             low            low         low               low
# 152             low         medium         low               low
# 197             low         medium         low               low
#
#     Trans Fat (g)  Category   wx    wy
# 201           low         3  0.0   9.0
# 188           low         3  0.0   9.0
# 180           low         3  0.0   9.0
# 152           low         3  0.5  10.0
# 197           low         3  1.0  11.0

# %%
recommended_food = recommend_food(random_food, df_std)
recommended_food
# Out:
#      Unnamed: 0                                               Name   Group  \
# 201         201                  Cloudberries, raw (Alaska Native)  fruits
# 188         188   Groundcherries, (cape-gooseberries or poha), raw  fruits
# 180         180  Cranberry, low bush or lingenberry, raw (Alask...  fruits
# 152         152           Grapefruit, raw, pink and red, all areas  fruits
# 197         197                                       Soursop, raw  fruits
#
#      GI Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 201   0             low         low      low       low       low       low
# 188   0             low         low      low    medium       low       low
# 180   0             low         low      low    medium       low       low
# 152   0             low         low      low    medium    medium    medium
# 197   0             low         low      low    medium    medium      high
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g)  \
# 201             low            low         low               low
# 188             low            low         low               low
# 180             low            low         low               low
# 152             low         medium         low               low
# 197             low         medium         low               low
#
#     Trans Fat (g)  Category   wx    wy
# 201           low         3  0.0   9.0
# 188           low         3  0.0   9.0
# 180           low         3  0.0   9.0
# 152           low         3  0.5  10.0
# 197           low         3  1.0  11.0

# %%
random_food
# Out:
#      Unnamed: 0             Name   Group  GI Calories (kcal) Protein (g)  \
# 177         177  Watermelon, raw  fruits   2             low         low
#
#     Fats (g) Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg)  \
# 177      low       low       low    medium             low         medium
#
#     Sodium (mg) Saturated Fat (g) Trans Fat (g)  Category   wx   wy
# 177         low               low           low         3 -0.5  8.0

# %%
def plot_difference(food1, food2):
  food1_numeric = df.loc[food1.index]
  food2_numeric = df.loc[food2.index]
  df_plot = pd.concat([food1_numeric,food2_numeric])
  df_plot.drop(["Unnamed: 0","Group", "wx", "wy", "Category"],axis=1, inplace=True)
  # df_new = df_plot.transpose().drop(["Unnamed: 0","Group", "Name", "wx", "wy"], axis=0)
  title= f"{df_plot['Name'].values[0]} vs {df_plot['Name'].values[1]}"
  df_plot.set_index("Name", inplace=True)
  df_plot.plot_bokeh.bar(ylabel="Nutrients range", xlabel="Food", title=title, legend = "top_right", figsize=(500, 200), sizing_mode="scale_width")

# %%
#@title
plot_difference(random_food, recommended_food.iloc[[0]])
# Out:
#   <div class="bk-root" id="a6173a6e-c3c7-4369-8a9f-5747bad17993" data-root-id="1038"></div>

# %%
#@title
plot_difference(random_food, recommended_food.iloc[[1]])
# Out:
#   <div class="bk-root" id="c6d5fa4c-526c-4d45-be5b-660c192a9652" data-root-id="1376"></div>

# %%
#@title
plot_difference(random_food, recommended_food.iloc[[2]])
# Out:
#   <div class="bk-root" id="aa3c65f5-ab1f-446c-a009-bcc2c362c70a" data-root-id="1722"></div>

# %%
#@title
plot_difference(random_food, recommended_food.iloc[[3]])
# Out:
#   <div class="bk-root" id="116fcd3a-58d8-4110-98f9-d2ed28dc9e60" data-root-id="2076"></div>

# %%
#@title
plot_difference(random_food, recommended_food.iloc[[4]])
# Out:
#   <div class="bk-root" id="7c905c72-3624-466d-acf8-b5fa854a271a" data-root-id="2438"></div>
