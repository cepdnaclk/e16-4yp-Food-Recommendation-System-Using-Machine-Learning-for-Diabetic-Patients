# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Category 0
df0 =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset_October25_Clustering/FoodData_group0.csv')
# Category 1
df1 =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset_October25_Clustering/FoodData_group1.csv')
# Category 2
df2 =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset_October25_Clustering/FoodData_group2.csv')
# Category 3
df3 =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset_October25_Clustering/FoodData_group3.csv')

# %%
# Combine all categories
df_all = pd.concat([df0, df1, df2, df3])

# %%
df_all.describe()
# Out:
#        Unnamed: 0          GI  Calories (kcal)  Protein (g)    Fats (g)  \
# count  550.000000  550.000000       550.000000   550.000000  550.000000
# mean   274.500000    0.307273       222.280000     8.440164   11.159473
# std    158.915596    0.589944       190.432003     9.259922   19.529972
# min      0.000000    0.000000         0.000000     0.000000    0.000000
# 25%    137.250000    0.000000        66.250000     1.202500    0.300000
# 50%    274.500000    0.000000       174.000000     4.510000    2.325000
# 75%    411.750000    0.000000       333.000000    14.207500   14.357500
# max    549.000000    2.000000       902.000000    75.160000  100.000000
#
#         Carbs (g)   Fiber (g)   Sugar (g)  Phosphorus (mg)  Potassium (mg)  \
# count  550.000000  550.000000  550.000000       550.000000       550.00000
# mean    22.772273    2.990545    7.148927       144.378182       299.46000
# std     25.272725    6.369072   15.503984       179.487143       356.45396
# min      0.000000    0.000000    0.000000         0.000000         0.00000
# 25%      3.335000    0.000000    0.000000        25.250000       112.00000
# 50%     12.865000    1.100000    1.045000        94.500000       203.00000
# 75%     33.457500    3.000000    6.180000       192.750000       355.75000
# max     99.980000   70.100000   99.800000      2191.000000      3020.00000
#
#         Sodium (mg)  Saturated Fat (g)  Trans Fat (g)    Category
# count    550.000000         550.000000     550.000000  550.000000
# mean     370.740000           3.628436       0.072564    1.834545
# std     2055.078385           7.626343       0.676744    1.116154
# min        0.000000           0.000000       0.000000    0.000000
# 25%        5.000000           0.040000       0.000000    1.000000
# 50%       44.000000           0.525000       0.000000    2.000000
# 75%      306.000000           3.800000       0.000000    3.000000
# max    38758.000000          82.480000      14.890000    3.000000

# %%
# Get numeric dataset
numeric = df_all.select_dtypes(include=np.number)
# Remove Category
numeric = numeric.drop(['Category', 'Unnamed: 0'], axis=1)
numeric_columns = numeric.columns

# %%
# Standardize data set
df_std = df_all.copy()
df_std[numeric_columns] = (numeric - numeric.mean())/numeric.std()

# %%
df_std.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           4             Cake, fruitcake, commercially prepared
# 1           6  Cake, pound, commercially prepared, butter (in...
# 2           7                   Cheesecake commercially prepared
# 3           9   Cookies, butter, commercially prepared, enriched
# 4          13  Cookies, shortbread, commercially prepared, plain
#
#             Group        GI  Calories (kcal)  Protein (g)  Fats (g)  \
# 0  baked-products -0.520850         0.534154    -0.598295 -0.105452
# 1  baked-products -0.520850         0.686439    -0.371511  0.143396
# 2  baked-products -0.520850         0.518400    -0.317515  0.580673
# 3  baked-products -0.520850         1.285078    -0.252720  0.391221
# 4  baked-products  1.174225         1.531885    -0.331554  0.771149
#
#    Carbs (g)  Fiber (g)  Sugar (g)  Phosphorus (mg)  Potassium (mg)  \
# 0   1.536349   0.111391   1.307475        -0.514679       -0.410881
# 1   1.221385  -0.375337   1.690602        -0.024393       -0.422102
# 2   0.107932  -0.406738   0.944988        -0.286250       -0.587621
# 3   1.825198  -0.343935   0.844368        -0.236107       -0.528708
# 4   1.622608  -0.265430   0.935313        -0.436679       -0.593232
#
#    Sodium (mg)  Saturated Fat (g)  Trans Fat (g)  Category
# 0    -0.131255          -0.338096      -0.107225         0
# 1     0.003046           0.154932       0.173531         0
# 2     0.032729           0.824978      -0.107225         0
# 3    -0.043181           0.973148      -0.107225         0
# 4    -0.008632           0.587643       0.941916         0

# %%
df_std = df_std.drop(["Unnamed: 0"], axis=1)

# %%
df_std["Group"].unique()
# Out:
# array(['baked-products', 'beverages', 'diary', 'fast-foods', 'grains',
#        'meat', 'oils-and-sauces', 'seafood', 'spices', 'sweets',
#        'vegetables', 'fruits', 'greens', 'meals-entrees-side-dishes',
#        'nuts', 'soups', 'mashrooms'], dtype=object)

# %%
for index,group in enumerate(df_std["Group"].unique()):
  sub_category = df_std[df_std["Group"]==group]
  sub_category.groupby("Category").mean().T.plot(kind="bar")
  plt.title(f"Variation of Nutrients in {group} product for different categories")
  plt.xlabel("Nutrients")
