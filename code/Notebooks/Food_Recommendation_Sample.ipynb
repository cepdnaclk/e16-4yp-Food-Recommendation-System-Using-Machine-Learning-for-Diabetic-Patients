# %% [markdown]
# #Setup & Functions

# %%
#@title
# Mount Google drive
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
#@title
# !pip install pandas_bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas_bokeh
#   Downloading pandas_bokeh-0.5.5-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: bokeh>=2.0 in /usr/local/lib/python3.7/dist-packages (from pandas_bokeh) (2.3.3)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from pandas_bokeh) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (2.8.2)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (4.1.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (2.11.3)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (6.0.4)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (21.3)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.0->pandas_bokeh) (1.21.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=2.0->pandas_bokeh) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=2.0->pandas_bokeh) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->pandas_bokeh) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=2.0->pandas_bokeh) (1.15.0)
# Installing collected packages: pandas-bokeh
# Successfully installed pandas-bokeh-0.5.5

# %%
#@title
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import distance

# %%
#@title
import pandas_bokeh
# Embedding plots in Jupyter/Colab Notebook
pandas_bokeh.output_notebook()

# %%
#@title
# Load datasets
df =pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset/SOM_FoodData_Nov15.csv')
df_cutoff = pd.read_csv(r'/gdrive/Shareddrives/FYP Project/Dataset/with_cutoff_values.csv')

# %%
#@title
# Food recommendation function
def recommend_food(selected_food, df_std):
  # Get data from selected food
  gi=selected_food["GI"].values[0]
  cat=selected_food["Category"].values[0]
  group=selected_food["Group"].values[0]
  wx=selected_food["wx"].values[0]
  wy=selected_food["wy"].values[0]

  # Select matching food considering GI, Group, Category
  selected_match = df_std[(df_std["GI"] < gi) & (df_std["Group"]==group) & (df_std["Category"]==cat)]
  # Calculate eucleadian distance
  distance_column = selected_match.apply(lambda x : np.sqrt((x.wx- wx)**2 + (x.wy-wy)**2), axis=1 )
  # return top 5 matching foods
  return selected_match.loc[distance_column.sort_values().index[:5],:]

# %%
#@title
# plot difference in nutrient of foods
def plot_difference(food1, food2):
  food1_numeric = df.loc[food1.index]
  food2_numeric = df.loc[food2.index]
  df_plot = pd.concat([food1_numeric,food2_numeric])
  df_plot.drop(["Unnamed: 0","Group", "wx", "wy", "Category"],axis=1, inplace=True)
  # df_new = df_plot.transpose().drop(["Unnamed: 0","Group", "Name", "wx", "wy"], axis=0)
  title= f"{df_plot['Name'].values[0]} vs {df_plot['Name'].values[1]}"
  df_plot.set_index("Name", inplace=True)
  df_plot.plot_bokeh.bar(ylabel="Nutrients range", xlabel="Food", title=title, legend = "top_right", figsize=(500, 200), sizing_mode="scale_width")

# %%
#@title
GI_high_food = df_cutoff[df_cutoff["GI"]==2]

# %%
#@title
# Return random food from given sub category with higher GI value
def get_random_food(category):
  sample = GI_high_food[GI_high_food["Group"]==category]
  if(len(sample)!=0):
    return sample.sample().iloc[[0]]
  else:
    print(f"{category} has 0 GI high foods")
    GI_medium_food = df_cutoff[df_cutoff["GI"]==1]
    sample = GI_medium_food[GI_medium_food["Group"]==category]
    if len(sample)!=0:
      return sample.sample().iloc[[0]]
    else:
      print(f"{category} has 0 GI medium foods")

# %% [markdown]
# #Milk and Milk Products

# %%
#@title
diary_food_GI_high=get_random_food("diary")

# %% [markdown]
# Randomly selected diary food with high GI value

# %%
#@title
diary_food_GI_high.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                  Name  Group  GI Calories (kcal) Protein (g)  \
# 119  Ice cream, soft serve, chocolate  diary   2            high         low
#
#     Fats (g) Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg)  \
# 119   medium    medium       low      high          medium         medium
#
#     Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 119         low              high           low

# %%
#@title
diary_recommends = recommend_food(diary_food_GI_high, df_cutoff)

# %% [markdown]
# Recommendation of low GI value diary foods

# %%
#@title
diary_recommends.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                                   Name  Group  GI  \
# 87   Milk, lowfat, fluid, 1% milkfat, with added vi...  diary   0
# 81       Cheese, cottage, creamed, large or small curd  diary   0
# 91                        Yogurt, Greek, plain, nonfat  diary   0
# 114                             Egg, white, raw, fresh  diary   0
# 112                         Milk shakes, thick vanilla  diary   0
#
#     Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 87              low         low      low       low       low    medium
# 81              low      medium      low       low       low    medium
# 91              low      medium      low       low       low    medium
# 114             low      medium      low       low       low       low
# 112          medium         low      low    medium       low      high
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 87              low         medium         low              high           low
# 81           medium         medium         low            medium           low
# 91           medium         medium         low            medium           low
# 114             low         medium         low               low           low
# 112          medium         medium         low              high           low

# %%
#@title
plot_difference(diary_food_GI_high, diary_recommends.iloc[[0]])
# Out:
#   <div class="bk-root" id="22cac47e-2b69-4483-9da6-335661d12336" data-root-id="1038"></div>

# %%
#@title
plot_difference(diary_food_GI_high, diary_recommends.iloc[[1]])
# Out:
#   <div class="bk-root" id="9d69e1b0-a061-4582-a8e6-ca63d345164b" data-root-id="1376"></div>

# %%
#@title
plot_difference(diary_food_GI_high, diary_recommends.iloc[[2]])
# Out:
#   <div class="bk-root" id="834537e4-3dd1-4fa2-b539-a6683b1ddab2" data-root-id="1722"></div>

# %%
#@title
plot_difference(diary_food_GI_high, diary_recommends.iloc[[3]])
# Out:
#   <div class="bk-root" id="d8344f5b-0362-49b7-a706-7c8b04f589f1" data-root-id="2076"></div>

# %%
#@title
plot_difference(diary_food_GI_high, diary_recommends.iloc[[4]])
# Out:
#   <div class="bk-root" id="a3084506-d305-4218-8d73-e6a8c259c386" data-root-id="2438"></div>

# %% [markdown]
# #Fruits

# %%
#@title
fruit_GI_High = get_random_food("fruits")

# %% [markdown]
# Randomly selected fruit with high GI value

# %%
#@title
fruit_GI_High.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                 Name   Group  GI Calories (kcal) Protein (g) Fats (g)  \
# 177  Watermelon, raw  fruits   2             low         low      low
#
#     Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg) Sodium (mg)  \
# 177       low       low    medium             low         medium         low
#
#     Saturated Fat (g) Trans Fat (g)
# 177               low           low

# %%
#@title
fruit_recommends = recommend_food(fruit_GI_High, df_cutoff)

# %% [markdown]
# Recommendation of low GI value fruits

# %%
#@title
fruit_recommends.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                                   Name   Group  GI  \
# 201                  Cloudberries, raw (Alaska Native)  fruits   0
# 188   Groundcherries, (cape-gooseberries or poha), raw  fruits   0
# 180  Cranberry, low bush or lingenberry, raw (Alask...  fruits   0
# 152           Grapefruit, raw, pink and red, all areas  fruits   0
# 197                                       Soursop, raw  fruits   0
#
#     Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 201             low         low      low       low       low       low
# 188             low         low      low    medium       low       low
# 180             low         low      low    medium       low       low
# 152             low         low      low    medium    medium    medium
# 197             low         low      low    medium    medium      high
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 201             low            low         low               low           low
# 188             low            low         low               low           low
# 180             low            low         low               low           low
# 152             low         medium         low               low           low
# 197             low         medium         low               low           low

# %%
#@title
plot_difference(fruit_GI_High, fruit_recommends.iloc[[0]])
# Out:
#   <div class="bk-root" id="44e5baa2-c84f-43a7-bf17-00b286409b68" data-root-id="2808"></div>

# %%
#@title
plot_difference(fruit_GI_High, fruit_recommends.iloc[[1]])
# Out:
#   <div class="bk-root" id="7c327c0a-43d7-4c68-b902-ff8e504d0eba" data-root-id="3186"></div>

# %%
#@title
plot_difference(fruit_GI_High, fruit_recommends.iloc[[2]])
# Out:
#   <div class="bk-root" id="b4d4c8bf-b60e-4ce0-b5e3-b47c87932b27" data-root-id="3572"></div>

# %%
#@title
plot_difference(fruit_GI_High, fruit_recommends.iloc[[3]])
# Out:
#   <div class="bk-root" id="deed6e3f-492f-4318-b1cc-0170fe34663a" data-root-id="3966"></div>

# %%
#@title
plot_difference(fruit_GI_High, fruit_recommends.iloc[[4]])
# Out:
#   <div class="bk-root" id="3c885c98-53df-4f42-9d71-ffa5041a414d" data-root-id="4368"></div>

# %% [markdown]
# #Vegetables

# %%
#@title
vegetables_GI_High = get_random_food("vegetables")

# %% [markdown]
# Randomly selected vegetable with high GI value

# %%
#@title
vegetables_GI_High.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#              Name       Group  GI Calories (kcal) Protein (g) Fats (g)  \
# 530  Cassava, raw  vegetables   2          medium         low      low
#
#     Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg) Sodium (mg)  \
# 530      high    medium       low             low         medium         low
#
#     Saturated Fat (g) Trans Fat (g)
# 530            medium           low

# %%
#@title
vegetable_recommends = recommend_food(vegetables_GI_High, df_cutoff)

# %% [markdown]
# Recommendation of low GI value vegetables

# %%
#@title
vegetable_recommends.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                               Name       Group  GI Calories (kcal)  \
# 508                    Garlic, raw  vegetables   0          medium
# 522                 Arrowroot, raw  vegetables   1             low
# 538  Sweet potato, raw, unprepared  vegetables   1             low
# 509               Ginger root, raw  vegetables   0             low
# 531                    Chives, raw  vegetables   0             low
#
#     Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg)  \
# 508         low      low      high    medium       low          medium
# 522         low      low    medium    medium       low             low
# 538         low      low    medium    medium    medium             low
# 509         low      low    medium    medium       low             low
# 531         low      low       low    medium       low             low
#
#     Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 508           high         low               low           low
# 522           high         low            medium           low
# 538           high         low            medium           low
# 509           high         low            medium           low
# 531         medium         low            medium           low

# %%
#@title
plot_difference(vegetables_GI_High, vegetable_recommends.iloc[[0]])
# Out:
#   <div class="bk-root" id="999df594-6117-4223-b884-466ff372470c" data-root-id="4778"></div>

# %%
#@title
plot_difference(vegetables_GI_High, vegetable_recommends.iloc[[1]])
# Out:
#   <div class="bk-root" id="ff35c18c-71fc-405c-86d8-b7dea0f4e9a3" data-root-id="5196"></div>

# %%
#@title
plot_difference(vegetables_GI_High, vegetable_recommends.iloc[[2]])
# Out:
#   <div class="bk-root" id="0ddba5a3-e5c0-4dae-9fa6-257f31da7a7e" data-root-id="5622"></div>

# %%
#@title
plot_difference(vegetables_GI_High, vegetable_recommends.iloc[[3]])
# Out:
#   <div class="bk-root" id="6e395c05-d4be-4266-91b5-dd3e2af72ddf" data-root-id="6056"></div>

# %%
#@title
plot_difference(vegetables_GI_High, vegetable_recommends.iloc[[4]])
# Out:
#   <div class="bk-root" id="0dcc4635-f2f5-4462-9a01-e7d094a4cac8" data-root-id="6498"></div>

# %% [markdown]
# #Seafoods

# %% [markdown]
# No seafoods found with high or medium GI values

# %%
#@title
seafood_GI_High = get_random_food("seafood")
# Out:
# seafood has 0 GI high foods
# seafood has 0 GI medium foods

# %% [markdown]
# #Meat

# %%
#@title
meat_GI_medium = get_random_food("meat")
# Out:
# meat has 0 GI high foods

# %% [markdown]
# Randomly selected  meat with medium GI value

# %%
#@title
meat_GI_medium.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                       Name Group  GI Calories (kcal) Protein (g) Fats (g)  \
# 340  Beef, cured, pastrami  meat   1          medium        high   medium
#
#     Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg) Potassium (mg) Sodium (mg)  \
# 340       low       low       low          medium         medium        high
#
#     Saturated Fat (g) Trans Fat (g)
# 340            medium           low

# %%
#@title
meat_recommends = recommend_food(meat_GI_medium, df_cutoff)

# %% [markdown]
# Recommendation of low GI value meat

# %%
#@title
meat_recommends.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                                   Name Group  GI  \
# 311  Pork, cured, ham, boneless, extra lean (approx...  meat   0
# 314                                     Frog legs, raw  meat   0
# 322                                      Bologna, pork  meat   0
# 333          Kielbasa, Polish, turkey and beef, smoked  meat   0
# 339          Beef, cured, corned beef, brisket, cooked  meat   0
#
#     Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 311          medium        high   medium       low       low       low
# 314             low      medium      low       low       low       low
# 322            high      medium     high       low       low       low
# 333            high      medium     high       low       low       low
# 339            high      medium     high       low       low       low
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 311          medium         medium        high            medium           low
# 314          medium         medium         low            medium           low
# 322          medium         medium      medium            medium           low
# 333             low            low        high            medium           low
# 339          medium         medium      medium            medium           low

# %%
#@title
plot_difference(meat_GI_medium, meat_recommends.iloc[[0]])
# Out:
#   <div class="bk-root" id="09422a26-16ea-4f65-8373-6692b663cbae" data-root-id="6948"></div>

# %%
#@title
plot_difference(meat_GI_medium, meat_recommends.iloc[[1]])
# Out:
#   <div class="bk-root" id="234f199a-a4ef-4ab7-9c84-3690eadf64ed" data-root-id="7406"></div>

# %%
#@title
plot_difference(meat_GI_medium, meat_recommends.iloc[[2]])
# Out:
#   <div class="bk-root" id="7dc29c2b-89d8-4a07-9aa0-3072e6706eba" data-root-id="7872"></div>

# %%
#@title
plot_difference(meat_GI_medium, meat_recommends.iloc[[3]])
# Out:
#   <div class="bk-root" id="4b989713-14ed-4ea7-87b4-b6d10e199666" data-root-id="8346"></div>

# %%
#@title
plot_difference(meat_GI_medium, meat_recommends.iloc[[4]])
# Out:
#   <div class="bk-root" id="6abd79f0-69fa-49a6-9fca-e3a0b5c82150" data-root-id="8828"></div>

# %% [markdown]
# #Grains

# %%
#@title
grains_GI_High = get_random_food("grains")

# %% [markdown]
# Randomly selected grains with high GI value

# %%
#@title
grains_GI_High.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                            Name   Group  GI Calories (kcal)  \
# 259  Rice, white, glutinous, unenriched, cooked  grains   2             low
#
#     Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g) Phosphorus (mg)  \
# 259         low      low    medium    medium       low             low
#
#     Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 259            low         low            medium           low

# %%
#@title
grains_recommends = recommend_food(grains_GI_High, df_cutoff)

# %% [markdown]
# Recommendation of low GI value grains

# %%
#@title
grains_recommends.drop(["Unnamed: 0","Unnamed: 0.1", "Category", "wx", "wy"], axis=1)
# Out:
#                                                   Name   Group  GI  \
# 239                    Rice, brown, long-grain, cooked  grains   1
# 257                  Buckwheat groats, roasted, cooked  grains   0
# 246                     Noodles, egg, enriched, cooked  grains   0
# 241  Rice, white, long-grain, regular, enriched, co...  grains   1
# 263  Rice, white, long-grain, regular, enriched, co...  grains   1
#
#     Calories (kcal) Protein (g) Fats (g) Carbs (g) Fiber (g) Sugar (g)  \
# 239          medium         low      low    medium    medium       low
# 257             low         low      low    medium    medium       low
# 246          medium         low      low    medium    medium       low
# 241          medium         low      low    medium       low       low
# 263          medium         low      low    medium       low       low
#
#     Phosphorus (mg) Potassium (mg) Sodium (mg) Saturated Fat (g) Trans Fat (g)
# 239          medium            low         low            medium           low
# 257             low            low         low            medium           low
# 246             low            low         low            medium           low
# 241             low            low         low            medium           low
# 263             low            low         low            medium           low

# %%
#@title
plot_difference(grains_GI_High, grains_recommends.iloc[[0]])
# Out:
#   <div class="bk-root" id="8052957a-b71b-433c-bcf9-4265664ba3d5" data-root-id="9318"></div>

# %%
#@title
plot_difference(grains_GI_High, grains_recommends.iloc[[1]])
# Out:
#   <div class="bk-root" id="3fefc84d-0b84-4a61-ba1a-2c143205d16a" data-root-id="9816"></div>

# %%
#@title
plot_difference(grains_GI_High, grains_recommends.iloc[[2]])
# Out:
#   <div class="bk-root" id="43c2e881-0c2c-4917-bc0c-a425577d38d5" data-root-id="10322"></div>

# %%
#@title
plot_difference(grains_GI_High, grains_recommends.iloc[[3]])
# Out:
#   <div class="bk-root" id="e58f92c4-3e7a-4b6a-8fb8-5bf818fe84a8" data-root-id="10836"></div>

# %%
#@title
plot_difference(grains_GI_High, grains_recommends.iloc[[4]])
# Out:
#   <div class="bk-root" id="1091d830-bfd7-43d3-9d9b-5be486d7e092" data-root-id="11358"></div>
